# %%
import csv
import pandas
import numpy

# %%
with open('/home/victor/development/calidad_aire/datos202012.csv', newline='') as File:  
    reader = csv.reader(File)
    idx = 1
    for row in reader:
        print(row)
        idx += 1
        if(idx > 16):
            break
# Out:
# ['PROVINCIA;MUNICIPIO;ESTACION;MAGNITUD;PUNTO_MUESTREO;ANO;MES;D01;V01;D02;V02;D03;V03;D04;V04;D05;V05;D06;V06;D07;V07;D08;V08;D09;V09;D10;V10;D11;V11;D12;V12;D13;V13;D14;V14;D15;V15;D16;V16;D17;V17;D18;V18;D19;V19;D20;V20;D21;V21;D22;V22;D23;V23;D24;V24;D25;V25;D26;V26;D27;V27;D28;V28;D29;V29;D30;V30;D31;V31']
# ['28;079;4;1;28079004_1_38;2020;01;00009;V;00010;V;00009;V;00007;V;00008;V;00009;V;00012;V;00014;V;00011;V;00009;V;00008;V;00009;V;00008;V;00009;V;00010;V;00011;V;00009;V;00008;V;00006;V;00004;N;00000;N;00000;N;00000;N;00000;N;00000;N;00000;N;00000;N;00000;N;00000;N;00006;N;00007;V']
# ['28;079;4;1;28079004_1_38;2020;02;00008;V;00009;V;00010;V;00011;V;00009;V;00009;V;00009;V;00010;V;00010;V;00009;V;00010;V;00010;V;00010;V;00009;V;00009;V;00010;V;00011;V;00010;V;00010;V;00010;V;00010;V;00011;V;00011;V;00011;V;00012;V;00010;V;00009;V;00011;V;00001;N;00000;N;00000;N']
# ...

# %%
# Spark: ver como hacer que Jupyter corra sobre Spark 
# https://medium.com/3blades-blog/how-to-use-jupyter-notebook-with-apache-spark-d935335de6bd

# %%
df = pandas.read_csv('/home/victor/development/calidad_aire/datos202012.csv', delimiter=';')
df
# Out:
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# 0            28         79         4         1  28079004_1_38  2020    1
# 1            28         79         4         1  28079004_1_38  2020    2
# 2            28         79         4         1  28079004_1_38  2020    3
# 3            28         79         4         1  28079004_1_38  2020    4
# 4            28         79         4         1  28079004_1_38  2020    5
# ...         ...        ...       ...       ...            ...   ...  ...
# 1831         28         79        60        14  28079060_14_6  2020    8
# 1832         28         79        60        14  28079060_14_6  2020    9
# 1833         28         79        60        14  28079060_14_6  2020   10
# 1834         28         79        60        14  28079060_14_6  2020   11
# 1835         28         79        60        14  28079060_14_6  2020   12
#
#        D01 V01   D02  ...   D27  V27   D28  V28   D29  V29   D30  V30   D31  \
# ...
